# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path(__file__).resolve().parent.parent if "__file__" in globals() else Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

print("CWD:", Path.cwd())
print("PROJECT_ROOT:", PROJECT_ROOT)
print("src import test:", (PROJECT_ROOT / "src").exists())
# Out:
# CWD: /Users/yaoxintong/Group4_Emergence-of-Structure-in-a-Simplified-Universe/notebooks
# PROJECT_ROOT: /Users/yaoxintong/Group4_Emergence-of-Structure-in-a-Simplified-Universe
# src import test: True

# %%
import os
import time
import numpy as np

from scipy.spatial import ConvexHull
from src.flocking_sim_3d import run_simulation


def unwrap_periodic(pos, box_size):
    pos = np.asarray(pos, dtype=float)
    com = pos.mean(axis=0)
    rel = pos - com
    rel -= box_size * np.round(rel / box_size)
    return com + rel


def pca_axes(pos):
    pos = np.asarray(pos, dtype=float)
    X = pos - pos.mean(axis=0, keepdims=True)
    C = (X.T @ X) / max(X.shape[0], 1)
    evals, _ = np.linalg.eigh(C)
    evals = np.sort(evals)[::-1]
    evals = np.maximum(evals, 0.0)
    I = np.sqrt(evals)
    I1, I2, I3 = float(I[0]), float(I[1]), float(I[2])
    return I1, I2, I3


def flock_volume_from_pca(pos):
    I1, I2, I3 = pca_axes(pos)
    V = (4.0 / 3.0) * np.pi * I1 * I2 * I3
    return float(V), (I1, I2, I3)


def hull_volume(pos):
    pos = np.asarray(pos, dtype=float)
    if pos.shape[0] < 4:
        return 0.0
    try:
        hull = ConvexHull(pos)
        return float(hull.volume)
    except Exception:
        return 0.0


def _standardize_history(history):
    h = np.asarray(history, dtype=float)
    if h.ndim != 3:
        raise ValueError(f"history must be 3D, got shape={h.shape}")
    if h.shape[-1] == 3:
        return h
    if h.shape[1] == 3:
        return np.transpose(h, (0, 2, 1))
    if h.shape[0] == 3:
        return np.transpose(h, (1, 2, 0))
    raise ValueError(f"cannot infer axis for xyz=3, got shape={h.shape}")


def compute_metrics(history, box_size, burn_frac=0.6):
    H = _standardize_history(history)
    T = H.shape[0]
    start = int(T * burn_frac)
    frames = H[start:] if start < T else H[-1:]

    dens = []
    hullV = []
    I2I1 = []
    I3I1 = []

    for pos in frames:
        pos_u = unwrap_periodic(pos, box_size)

        Vpca, (I1, I2, I3) = flock_volume_from_pca(pos_u)
        dens.append(pos_u.shape[0] / (Vpca + 1e-12))

        Vh = hull_volume(pos_u)
        hullV.append(Vh)

        I2I1.append(I2 / (I1 + 1e-12))
        I3I1.append(I3 / (I1 + 1e-12))

    dens = np.asarray(dens, dtype=float)
    hullV = np.asarray(hullV, dtype=float)
    I2I1 = np.asarray(I2I1, dtype=float)
    I3I1 = np.asarray(I3I1, dtype=float)

    return {
        "density_mean": float(np.mean(dens)),
        "density_std": float(np.std(dens)),
        "hullV_mean": float(np.mean(hullV)),
        "hullV_std": float(np.std(hullV)),
        "I2I1_mean": float(np.mean(I2I1)),
        "I2I1_std": float(np.std(I2I1)),
        "I3I1_mean": float(np.mean(I3I1)),
        "I3I1_std": float(np.std(I3I1)),
    }


def run_one_setting(params, seed):
    kwargs = dict(params)
    kwargs["seed"] = int(seed)
    history = run_simulation(**kwargs)
    return history


def sweep_3d(
    align_vals,
    cohesion_vals,
    noise_vals,
    seeds,
    sim_params,
    burn_frac=0.6,
    out_path="sweep3d_align_cohesion_noise.npz",
    overwrite=True,
    progress_every=1,
):
    align_vals = np.asarray(align_vals, dtype=float)
    cohesion_vals = np.asarray(cohesion_vals, dtype=float)
    noise_vals = np.asarray(noise_vals, dtype=float)
    seeds = list(seeds)

    if (not overwrite) and os.path.exists(out_path):
        raise FileExistsError(out_path)

    shape = (len(align_vals), len(cohesion_vals), len(noise_vals))

    density = np.full(shape, np.nan)
    density_std_across_seeds = np.full(shape, np.nan)

    hullV = np.full(shape, np.nan)
    hullV_std_across_seeds = np.full(shape, np.nan)

    I2I1 = np.full(shape, np.nan)
    I2I1_std_across_seeds = np.full(shape, np.nan)

    I3I1 = np.full(shape, np.nan)
    I3I1_std_across_seeds = np.full(shape, np.nan)

    total = len(align_vals) * len(cohesion_vals) * len(noise_vals) * len(seeds)
    done = 0
    t0 = time.time()

    for i, align in enumerate(align_vals):
        for j, cohesion in enumerate(cohesion_vals):
            for k, noise in enumerate(noise_vals):
                runs = []
                for seed in seeds:
                    params = dict(sim_params)
                    params["align"] = float(align)
                    params["cohesion"] = float(cohesion)
                    params["noise"] = float(noise)

                    history = run_one_setting(params, seed)
                    m = compute_metrics(history, box_size=float(sim_params["box_size"]), burn_frac=burn_frac)
                    runs.append(m)

                    done += 1
                    if progress_every and (done % progress_every == 0):
                        elapsed = time.time() - t0
                        rate = done / max(elapsed, 1e-9)
                        print(f"[{done}/{total}] align={align:.3f} cohesion={cohesion:.3f} noise={noise:.3f} seed={seed} | {rate:.2f} runs/s")

                dens_means = np.array([m["density_mean"] for m in runs], dtype=float)
                hull_means = np.array([m["hullV_mean"] for m in runs], dtype=float)
                i2i1_means = np.array([m["I2I1_mean"] for m in runs], dtype=float)
                i3i1_means = np.array([m["I3I1_mean"] for m in runs], dtype=float)

                density[i, j, k] = float(np.mean(dens_means))
                density_std_across_seeds[i, j, k] = float(np.std(dens_means))

                hullV[i, j, k] = float(np.mean(hull_means))
                hullV_std_across_seeds[i, j, k] = float(np.std(hull_means))

                I2I1[i, j, k] = float(np.mean(i2i1_means))
                I2I1_std_across_seeds[i, j, k] = float(np.std(i2i1_means))

                I3I1[i, j, k] = float(np.mean(i3i1_means))
                I3I1_std_across_seeds[i, j, k] = float(np.std(i3i1_means))

    np.savez(
        out_path,
        align_vals=align_vals,
        cohesion_vals=cohesion_vals,
        noise_vals=noise_vals,
        seeds=np.array(seeds, dtype=int),
        burn_frac=float(burn_frac),
        density=density,
        density_std_across_seeds=density_std_across_seeds,
        hullV=hullV,
        hullV_std_across_seeds=hullV_std_across_seeds,
        I2I1=I2I1,
        I2I1_std_across_seeds=I2I1_std_across_seeds,
        I3I1=I3I1,
        I3I1_std_across_seeds=I3I1_std_across_seeds,
        **{f"sim_{k}": np.array(v) if isinstance(v, (list, tuple, np.ndarray)) else v for k, v in sim_params.items()},
    )

    return out_path


align_vals = [0.0, 0.5, 1.0, 1.5, 2.0]
cohesion_vals = [0.0, 0.2, 0.4, 0.6]
noise_vals = [0.0, 0.03, 0.06, 0.09, 0.12]
seeds = [0, 1, 2]

sim_params = dict(
    N=200,
    steps=600,
    box_size=1.0,
    R=0.15,
    speed=0.03,
    repulsion_radius=0.05,
    repulsion_strength=1.0,
    dt=0.1,
    save_every=1,
    softening=1e-6,
    use_predator=False,
)

out_file = sweep_3d(
    align_vals=align_vals,
    cohesion_vals=cohesion_vals,
    noise_vals=noise_vals,
    seeds=seeds,
    sim_params=sim_params,
    burn_frac=0.6,
    out_path="sweep3d_align_cohesion_noise.npz",
    overwrite=True,
    progress_every=1,
)

print("saved:", out_file)
# Out:
# [1/300] align=0.000 cohesion=0.000 noise=0.000 seed=0 | 0.84 runs/s
# [2/300] align=0.000 cohesion=0.000 noise=0.000 seed=1 | 0.87 runs/s
# [3/300] align=0.000 cohesion=0.000 noise=0.000 seed=2 | 0.87 runs/s
# [4/300] align=0.000 cohesion=0.000 noise=0.030 seed=0 | 0.86 runs/s
# [5/300] align=0.000 cohesion=0.000 noise=0.030 seed=1 | 0.86 runs/s
# [6/300] align=0.000 cohesion=0.000 noise=0.030 seed=2 | 0.86 runs/s
# [7/300] align=0.000 cohesion=0.000 noise=0.060 seed=0 | 0.86 runs/s
# [8/300] align=0.000 cohesion=0.000 noise=0.060 seed=1 | 0.86 runs/s
# [9/300] align=0.000 cohesion=0.000 noise=0.060 seed=2 | 0.86 runs/s
# [10/300] align=0.000 cohesion=0.000 noise=0.090 seed=0 | 0.87 runs/s
# [11/300] align=0.000 cohesion=0.000 noise=0.090 seed=1 | 0.86 runs/s
# [12/300] align=0.000 cohesion=0.000 noise=0.090 seed=2 | 0.86 runs/s
# [13/300] align=0.000 cohesion=0.000 noise=0.120 seed=0 | 0.86 runs/s
# [14/300] align=0.000 cohesion=0.000 noise=0.120 seed=1 | 0.86 runs/s
# [15/300] align=0.000 cohesion=0.000 noise=0.120 seed=2 | 0.86 runs/s
# [16/300] align=0.000 cohesion=0.200 noise=0.000 seed=0 | 0.86 runs/s
# [17/300] align=0.000 cohesion=0.200 noise=0.000 seed=1 | 0.86 runs/s
# [18/300] align=0.000 cohesion=0.200 noise=0.000 seed=2 | 0.86 runs/s
# [19/300] align=0.000 cohesion=0.200 noise=0.030 seed=0 | 0.86 runs/s
# [20/300] align=0.000 cohesion=0.200 noise=0.030 seed=1 | 0.86 runs/s
# [21/300] align=0.000 cohesion=0.200 noise=0.030 seed=2 | 0.86 runs/s
# [22/300] align=0.000 cohesion=0.200 noise=0.060 seed=0 | 0.86 runs/s
# [23/300] align=0.000 cohesion=0.200 noise=0.060 seed=1 | 0.86 runs/s
# [24/300] align=0.000 cohesion=0.200 noise=0.060 seed=2 | 0.86 runs/s
# [25/300] align=0.000 cohesion=0.200 noise=0.090 seed=0 | 0.86 runs/s
# [26/300] align=0.000 cohesion=0.200 noise=0.090 seed=1 | 0.86 runs/s
# [27/300] align=0.000 cohesion=0.200 noise=0.090 seed=2 | 0.86 runs/s
# [28/300] align=0.000 cohesion=0.200 noise=0.120 seed=0 | 0.86 runs/s
# [29/300] align=0.000 cohesion=0.200 noise=0.120 seed=1 | 0.86 runs/s
# [30/300] align=0.000 cohesion=0.200 noise=0.120 seed=2 | 0.86 runs/s
# [31/300] align=0.000 cohesion=0.400 noise=0.000 seed=0 | 0.86 runs/s
# [32/300] align=0.000 cohesion=0.400 noise=0.000 seed=1 | 0.86 runs/s
# [33/300] align=0.000 cohesion=0.400 noise=0.000 seed=2 | 0.86 runs/s
# [34/300] align=0.000 cohesion=0.400 noise=0.030 seed=0 | 0.86 runs/s
# [35/300] align=0.000 cohesion=0.400 noise=0.030 seed=1 | 0.86 runs/s
# [36/300] align=0.000 cohesion=0.400 noise=0.030 seed=2 | 0.86 runs/s
# [37/300] align=0.000 cohesion=0.400 noise=0.060 seed=0 | 0.86 runs/s
# [38/300] align=0.000 cohesion=0.400 noise=0.060 seed=1 | 0.86 runs/s
# [39/300] align=0.000 cohesion=0.400 noise=0.060 seed=2 | 0.86 runs/s
# [40/300] align=0.000 cohesion=0.400 noise=0.090 seed=0 | 0.86 runs/s
# [41/300] align=0.000 cohesion=0.400 noise=0.090 seed=1 | 0.86 runs/s
# [42/300] align=0.000 cohesion=0.400 noise=0.090 seed=2 | 0.86 runs/s
# [43/300] align=0.000 cohesion=0.400 noise=0.120 seed=0 | 0.86 runs/s
# [44/300] align=0.000 cohesion=0.400 noise=0.120 seed=1 | 0.86 runs/s
# [45/300] align=0.000 cohesion=0.400 noise=0.120 seed=2 | 0.86 runs/s
# [46/300] align=0.000 cohesion=0.600 noise=0.000 seed=0 | 0.86 runs/s
# [47/300] align=0.000 cohesion=0.600 noise=0.000 seed=1 | 0.86 runs/s
# [48/300] align=0.000 cohesion=0.600 noise=0.000 seed=2 | 0.86 runs/s
# [49/300] align=0.000 cohesion=0.600 noise=0.030 seed=0 | 0.86 runs/s
# [50/300] align=0.000 cohesion=0.600 noise=0.030 seed=1 | 0.86 runs/s
# [51/300] align=0.000 cohesion=0.600 noise=0.030 seed=2 | 0.86 runs/s
# [52/300] align=0.000 cohesion=0.600 noise=0.060 seed=0 | 0.86 runs/s
# [53/300] align=0.000 cohesion=0.600 noise=0.060 seed=1 | 0.86 runs/s
# [54/300] align=0.000 cohesion=0.600 noise=0.060 seed=2 | 0.86 runs/s
# [55/300] align=0.000 cohesion=0.600 noise=0.090 seed=0 | 0.86 runs/s
# [56/300] align=0.000 cohesion=0.600 noise=0.090 seed=1 | 0.86 runs/s
# [57/300] align=0.000 cohesion=0.600 noise=0.090 seed=2 | 0.86 runs/s
# [58/300] align=0.000 cohesion=0.600 noise=0.120 seed=0 | 0.86 runs/s
# [59/300] align=0.000 cohesion=0.600 noise=0.120 seed=1 | 0.86 runs/s
# [60/300] align=0.000 cohesion=0.600 noise=0.120 seed=2 | 0.86 runs/s
# [61/300] align=0.500 cohesion=0.000 noise=0.000 seed=0 | 0.86 runs/s
# [62/300] align=0.500 cohesion=0.000 noise=0.000 seed=1 | 0.86 runs/s
# [63/300] align=0.500 cohesion=0.000 noise=0.000 seed=2 | 0.86 runs/s
# [64/300] align=0.500 cohesion=0.000 noise=0.030 seed=0 | 0.86 runs/s
# [65/300] align=0.500 cohesion=0.000 noise=0.030 seed=1 | 0.86 runs/s
# [66/300] align=0.500 cohesion=0.000 noise=0.030 seed=2 | 0.86 runs/s
# [67/300] align=0.500 cohesion=0.000 noise=0.060 seed=0 | 0.86 runs/s
# [68/300] align=0.500 cohesion=0.000 noise=0.060 seed=1 | 0.86 runs/s
# [69/300] align=0.500 cohesion=0.000 noise=0.060 seed=2 | 0.86 runs/s
# [70/300] align=0.500 cohesion=0.000 noise=0.090 seed=0 | 0.86 runs/s
# [71/300] align=0.500 cohesion=0.000 noise=0.090 seed=1 | 0.86 runs/s
# [72/300] align=0.500 cohesion=0.000 noise=0.090 seed=2 | 0.86 runs/s
# [73/300] align=0.500 cohesion=0.000 noise=0.120 seed=0 | 0.86 runs/s
# [74/300] align=0.500 cohesion=0.000 noise=0.120 seed=1 | 0.86 runs/s
# [75/300] align=0.500 cohesion=0.000 noise=0.120 seed=2 | 0.86 runs/s
# [76/300] align=0.500 cohesion=0.200 noise=0.000 seed=0 | 0.86 runs/s
# [77/300] align=0.500 cohesion=0.200 noise=0.000 seed=1 | 0.86 runs/s
# [78/300] align=0.500 cohesion=0.200 noise=0.000 seed=2 | 0.86 runs/s
# [79/300] align=0.500 cohesion=0.200 noise=0.030 seed=0 | 0.86 runs/s
# [80/300] align=0.500 cohesion=0.200 noise=0.030 seed=1 | 0.86 runs/s
# [81/300] align=0.500 cohesion=0.200 noise=0.030 seed=2 | 0.86 runs/s
# [82/300] align=0.500 cohesion=0.200 noise=0.060 seed=0 | 0.86 runs/s
# [83/300] align=0.500 cohesion=0.200 noise=0.060 seed=1 | 0.86 runs/s
# [84/300] align=0.500 cohesion=0.200 noise=0.060 seed=2 | 0.86 runs/s
# [85/300] align=0.500 cohesion=0.200 noise=0.090 seed=0 | 0.86 runs/s
# [86/300] align=0.500 cohesion=0.200 noise=0.090 seed=1 | 0.86 runs/s
# [87/300] align=0.500 cohesion=0.200 noise=0.090 seed=2 | 0.86 runs/s
# [88/300] align=0.500 cohesion=0.200 noise=0.120 seed=0 | 0.86 runs/s
# [89/300] align=0.500 cohesion=0.200 noise=0.120 seed=1 | 0.86 runs/s
# [90/300] align=0.500 cohesion=0.200 noise=0.120 seed=2 | 0.86 runs/s
# [91/300] align=0.500 cohesion=0.400 noise=0.000 seed=0 | 0.86 runs/s
# [92/300] align=0.500 cohesion=0.400 noise=0.000 seed=1 | 0.86 runs/s
# [93/300] align=0.500 cohesion=0.400 noise=0.000 seed=2 | 0.86 runs/s
# [94/300] align=0.500 cohesion=0.400 noise=0.030 seed=0 | 0.86 runs/s
# [95/300] align=0.500 cohesion=0.400 noise=0.030 seed=1 | 0.86 runs/s
# [96/300] align=0.500 cohesion=0.400 noise=0.030 seed=2 | 0.86 runs/s
# [97/300] align=0.500 cohesion=0.400 noise=0.060 seed=0 | 0.86 runs/s
# [98/300] align=0.500 cohesion=0.400 noise=0.060 seed=1 | 0.86 runs/s
# [99/300] align=0.500 cohesion=0.400 noise=0.060 seed=2 | 0.86 runs/s
# [100/300] align=0.500 cohesion=0.400 noise=0.090 seed=0 | 0.86 runs/s
# [101/300] align=0.500 cohesion=0.400 noise=0.090 seed=1 | 0.86 runs/s
# [102/300] align=0.500 cohesion=0.400 noise=0.090 seed=2 | 0.86 runs/s
# [103/300] align=0.500 cohesion=0.400 noise=0.120 seed=0 | 0.86 runs/s
# [104/300] align=0.500 cohesion=0.400 noise=0.120 seed=1 | 0.86 runs/s
# [105/300] align=0.500 cohesion=0.400 noise=0.120 seed=2 | 0.86 runs/s
# [106/300] align=0.500 cohesion=0.600 noise=0.000 seed=0 | 0.86 runs/s
# [107/300] align=0.500 cohesion=0.600 noise=0.000 seed=1 | 0.86 runs/s
# [108/300] align=0.500 cohesion=0.600 noise=0.000 seed=2 | 0.86 runs/s
# [109/300] align=0.500 cohesion=0.600 noise=0.030 seed=0 | 0.86 runs/s
# [110/300] align=0.500 cohesion=0.600 noise=0.030 seed=1 | 0.86 runs/s
# [111/300] align=0.500 cohesion=0.600 noise=0.030 seed=2 | 0.86 runs/s
# [112/300] align=0.500 cohesion=0.600 noise=0.060 seed=0 | 0.86 runs/s
# [113/300] align=0.500 cohesion=0.600 noise=0.060 seed=1 | 0.86 runs/s
# [114/300] align=0.500 cohesion=0.600 noise=0.060 seed=2 | 0.86 runs/s
# [115/300] align=0.500 cohesion=0.600 noise=0.090 seed=0 | 0.86 runs/s
# [116/300] align=0.500 cohesion=0.600 noise=0.090 seed=1 | 0.86 runs/s
# [117/300] align=0.500 cohesion=0.600 noise=0.090 seed=2 | 0.86 runs/s
# [118/300] align=0.500 cohesion=0.600 noise=0.120 seed=0 | 0.86 runs/s
# [119/300] align=0.500 cohesion=0.600 noise=0.120 seed=1 | 0.86 runs/s
# [120/300] align=0.500 cohesion=0.600 noise=0.120 seed=2 | 0.86 runs/s
# [121/300] align=1.000 cohesion=0.000 noise=0.000 seed=0 | 0.86 runs/s
# [122/300] align=1.000 cohesion=0.000 noise=0.000 seed=1 | 0.86 runs/s
# [123/300] align=1.000 cohesion=0.000 noise=0.000 seed=2 | 0.86 runs/s
# [124/300] align=1.000 cohesion=0.000 noise=0.030 seed=0 | 0.86 runs/s
# [125/300] align=1.000 cohesion=0.000 noise=0.030 seed=1 | 0.86 runs/s
# [126/300] align=1.000 cohesion=0.000 noise=0.030 seed=2 | 0.86 runs/s
# [127/300] align=1.000 cohesion=0.000 noise=0.060 seed=0 | 0.86 runs/s
# [128/300] align=1.000 cohesion=0.000 noise=0.060 seed=1 | 0.86 runs/s
# [129/300] align=1.000 cohesion=0.000 noise=0.060 seed=2 | 0.86 runs/s
# [130/300] align=1.000 cohesion=0.000 noise=0.090 seed=0 | 0.86 runs/s
# [131/300] align=1.000 cohesion=0.000 noise=0.090 seed=1 | 0.86 runs/s
# [132/300] align=1.000 cohesion=0.000 noise=0.090 seed=2 | 0.86 runs/s
# [133/300] align=1.000 cohesion=0.000 noise=0.120 seed=0 | 0.86 runs/s
# [134/300] align=1.000 cohesion=0.000 noise=0.120 seed=1 | 0.86 runs/s
# [135/300] align=1.000 cohesion=0.000 noise=0.120 seed=2 | 0.86 runs/s
# [136/300] align=1.000 cohesion=0.200 noise=0.000 seed=0 | 0.86 runs/s
# [137/300] align=1.000 cohesion=0.200 noise=0.000 seed=1 | 0.86 runs/s
# [138/300] align=1.000 cohesion=0.200 noise=0.000 seed=2 | 0.86 runs/s
# [139/300] align=1.000 cohesion=0.200 noise=0.030 seed=0 | 0.86 runs/s
# [140/300] align=1.000 cohesion=0.200 noise=0.030 seed=1 | 0.86 runs/s
# [141/300] align=1.000 cohesion=0.200 noise=0.030 seed=2 | 0.86 runs/s
# [142/300] align=1.000 cohesion=0.200 noise=0.060 seed=0 | 0.86 runs/s
# [143/300] align=1.000 cohesion=0.200 noise=0.060 seed=1 | 0.86 runs/s
# [144/300] align=1.000 cohesion=0.200 noise=0.060 seed=2 | 0.86 runs/s
# [145/300] align=1.000 cohesion=0.200 noise=0.090 seed=0 | 0.86 runs/s
# [146/300] align=1.000 cohesion=0.200 noise=0.090 seed=1 | 0.86 runs/s
# [147/300] align=1.000 cohesion=0.200 noise=0.090 seed=2 | 0.86 runs/s
# [148/300] align=1.000 cohesion=0.200 noise=0.120 seed=0 | 0.86 runs/s
# [149/300] align=1.000 cohesion=0.200 noise=0.120 seed=1 | 0.86 runs/s
# [150/300] align=1.000 cohesion=0.200 noise=0.120 seed=2 | 0.86 runs/s
# [151/300] align=1.000 cohesion=0.400 noise=0.000 seed=0 | 0.86 runs/s
# [152/300] align=1.000 cohesion=0.400 noise=0.000 seed=1 | 0.86 runs/s
# [153/300] align=1.000 cohesion=0.400 noise=0.000 seed=2 | 0.86 runs/s
# [154/300] align=1.000 cohesion=0.400 noise=0.030 seed=0 | 0.86 runs/s
# [155/300] align=1.000 cohesion=0.400 noise=0.030 seed=1 | 0.86 runs/s
# [156/300] align=1.000 cohesion=0.400 noise=0.030 seed=2 | 0.86 runs/s
# [157/300] align=1.000 cohesion=0.400 noise=0.060 seed=0 | 0.86 runs/s
# [158/300] align=1.000 cohesion=0.400 noise=0.060 seed=1 | 0.86 runs/s
# [159/300] align=1.000 cohesion=0.400 noise=0.060 seed=2 | 0.86 runs/s
# [160/300] align=1.000 cohesion=0.400 noise=0.090 seed=0 | 0.85 runs/s
# [161/300] align=1.000 cohesion=0.400 noise=0.090 seed=1 | 0.85 runs/s
# [162/300] align=1.000 cohesion=0.400 noise=0.090 seed=2 | 0.85 runs/s
# [163/300] align=1.000 cohesion=0.400 noise=0.120 seed=0 | 0.85 runs/s
# [164/300] align=1.000 cohesion=0.400 noise=0.120 seed=1 | 0.85 runs/s
# [165/300] align=1.000 cohesion=0.400 noise=0.120 seed=2 | 0.85 runs/s
# [166/300] align=1.000 cohesion=0.600 noise=0.000 seed=0 | 0.85 runs/s
# [167/300] align=1.000 cohesion=0.600 noise=0.000 seed=1 | 0.85 runs/s
# [168/300] align=1.000 cohesion=0.600 noise=0.000 seed=2 | 0.85 runs/s
# [169/300] align=1.000 cohesion=0.600 noise=0.030 seed=0 | 0.85 runs/s
# [170/300] align=1.000 cohesion=0.600 noise=0.030 seed=1 | 0.85 runs/s
# [171/300] align=1.000 cohesion=0.600 noise=0.030 seed=2 | 0.85 runs/s
# [172/300] align=1.000 cohesion=0.600 noise=0.060 seed=0 | 0.85 runs/s
# [173/300] align=1.000 cohesion=0.600 noise=0.060 seed=1 | 0.85 runs/s
# [174/300] align=1.000 cohesion=0.600 noise=0.060 seed=2 | 0.85 runs/s
# [175/300] align=1.000 cohesion=0.600 noise=0.090 seed=0 | 0.85 runs/s
# [176/300] align=1.000 cohesion=0.600 noise=0.090 seed=1 | 0.85 runs/s
# [177/300] align=1.000 cohesion=0.600 noise=0.090 seed=2 | 0.85 runs/s
# [178/300] align=1.000 cohesion=0.600 noise=0.120 seed=0 | 0.85 runs/s
# [179/300] align=1.000 cohesion=0.600 noise=0.120 seed=1 | 0.85 runs/s
# [180/300] align=1.000 cohesion=0.600 noise=0.120 seed=2 | 0.85 runs/s
# [181/300] align=1.500 cohesion=0.000 noise=0.000 seed=0 | 0.85 runs/s
# [182/300] align=1.500 cohesion=0.000 noise=0.000 seed=1 | 0.85 runs/s
# [183/300] align=1.500 cohesion=0.000 noise=0.000 seed=2 | 0.85 runs/s
# [184/300] align=1.500 cohesion=0.000 noise=0.030 seed=0 | 0.85 runs/s
# [185/300] align=1.500 cohesion=0.000 noise=0.030 seed=1 | 0.85 runs/s
# [186/300] align=1.500 cohesion=0.000 noise=0.030 seed=2 | 0.85 runs/s
# [187/300] align=1.500 cohesion=0.000 noise=0.060 seed=0 | 0.85 runs/s
# [188/300] align=1.500 cohesion=0.000 noise=0.060 seed=1 | 0.85 runs/s
# [189/300] align=1.500 cohesion=0.000 noise=0.060 seed=2 | 0.85 runs/s
# [190/300] align=1.500 cohesion=0.000 noise=0.090 seed=0 | 0.85 runs/s
# [191/300] align=1.500 cohesion=0.000 noise=0.090 seed=1 | 0.85 runs/s
# [192/300] align=1.500 cohesion=0.000 noise=0.090 seed=2 | 0.85 runs/s
# [193/300] align=1.500 cohesion=0.000 noise=0.120 seed=0 | 0.85 runs/s
# [194/300] align=1.500 cohesion=0.000 noise=0.120 seed=1 | 0.85 runs/s
# [195/300] align=1.500 cohesion=0.000 noise=0.120 seed=2 | 0.85 runs/s
# [196/300] align=1.500 cohesion=0.200 noise=0.000 seed=0 | 0.85 runs/s
# [197/300] align=1.500 cohesion=0.200 noise=0.000 seed=1 | 0.85 runs/s
# [198/300] align=1.500 cohesion=0.200 noise=0.000 seed=2 | 0.85 runs/s
# [199/300] align=1.500 cohesion=0.200 noise=0.030 seed=0 | 0.85 runs/s
# [200/300] align=1.500 cohesion=0.200 noise=0.030 seed=1 | 0.85 runs/s
# [201/300] align=1.500 cohesion=0.200 noise=0.030 seed=2 | 0.85 runs/s
# [202/300] align=1.500 cohesion=0.200 noise=0.060 seed=0 | 0.85 runs/s
# [203/300] align=1.500 cohesion=0.200 noise=0.060 seed=1 | 0.85 runs/s
# [204/300] align=1.500 cohesion=0.200 noise=0.060 seed=2 | 0.85 runs/s
# [205/300] align=1.500 cohesion=0.200 noise=0.090 seed=0 | 0.85 runs/s
# [206/300] align=1.500 cohesion=0.200 noise=0.090 seed=1 | 0.85 runs/s
# [207/300] align=1.500 cohesion=0.200 noise=0.090 seed=2 | 0.85 runs/s
# [208/300] align=1.500 cohesion=0.200 noise=0.120 seed=0 | 0.85 runs/s
# [209/300] align=1.500 cohesion=0.200 noise=0.120 seed=1 | 0.85 runs/s
# [210/300] align=1.500 cohesion=0.200 noise=0.120 seed=2 | 0.85 runs/s
# [211/300] align=1.500 cohesion=0.400 noise=0.000 seed=0 | 0.85 runs/s
# [212/300] align=1.500 cohesion=0.400 noise=0.000 seed=1 | 0.85 runs/s
# [213/300] align=1.500 cohesion=0.400 noise=0.000 seed=2 | 0.85 runs/s
# [214/300] align=1.500 cohesion=0.400 noise=0.030 seed=0 | 0.85 runs/s
# [215/300] align=1.500 cohesion=0.400 noise=0.030 seed=1 | 0.85 runs/s
# [216/300] align=1.500 cohesion=0.400 noise=0.030 seed=2 | 0.85 runs/s
# [217/300] align=1.500 cohesion=0.400 noise=0.060 seed=0 | 0.85 runs/s
# [218/300] align=1.500 cohesion=0.400 noise=0.060 seed=1 | 0.85 runs/s
# [219/300] align=1.500 cohesion=0.400 noise=0.060 seed=2 | 0.85 runs/s
# [220/300] align=1.500 cohesion=0.400 noise=0.090 seed=0 | 0.85 runs/s
# [221/300] align=1.500 cohesion=0.400 noise=0.090 seed=1 | 0.85 runs/s
# [222/300] align=1.500 cohesion=0.400 noise=0.090 seed=2 | 0.85 runs/s
# [223/300] align=1.500 cohesion=0.400 noise=0.120 seed=0 | 0.85 runs/s
# [224/300] align=1.500 cohesion=0.400 noise=0.120 seed=1 | 0.85 runs/s
# [225/300] align=1.500 cohesion=0.400 noise=0.120 seed=2 | 0.85 runs/s
# [226/300] align=1.500 cohesion=0.600 noise=0.000 seed=0 | 0.85 runs/s
# [227/300] align=1.500 cohesion=0.600 noise=0.000 seed=1 | 0.85 runs/s
# [228/300] align=1.500 cohesion=0.600 noise=0.000 seed=2 | 0.85 runs/s
# [229/300] align=1.500 cohesion=0.600 noise=0.030 seed=0 | 0.85 runs/s
# [230/300] align=1.500 cohesion=0.600 noise=0.030 seed=1 | 0.85 runs/s
# [231/300] align=1.500 cohesion=0.600 noise=0.030 seed=2 | 0.85 runs/s
# [232/300] align=1.500 cohesion=0.600 noise=0.060 seed=0 | 0.85 runs/s
# [233/300] align=1.500 cohesion=0.600 noise=0.060 seed=1 | 0.85 runs/s
# [234/300] align=1.500 cohesion=0.600 noise=0.060 seed=2 | 0.85 runs/s
# [235/300] align=1.500 cohesion=0.600 noise=0.090 seed=0 | 0.85 runs/s
# [236/300] align=1.500 cohesion=0.600 noise=0.090 seed=1 | 0.85 runs/s
# [237/300] align=1.500 cohesion=0.600 noise=0.090 seed=2 | 0.85 runs/s
# [238/300] align=1.500 cohesion=0.600 noise=0.120 seed=0 | 0.85 runs/s
# [239/300] align=1.500 cohesion=0.600 noise=0.120 seed=1 | 0.85 runs/s
# [240/300] align=1.500 cohesion=0.600 noise=0.120 seed=2 | 0.85 runs/s
# [241/300] align=2.000 cohesion=0.000 noise=0.000 seed=0 | 0.85 runs/s
# [242/300] align=2.000 cohesion=0.000 noise=0.000 seed=1 | 0.85 runs/s
# [243/300] align=2.000 cohesion=0.000 noise=0.000 seed=2 | 0.85 runs/s
# [244/300] align=2.000 cohesion=0.000 noise=0.030 seed=0 | 0.85 runs/s
# [245/300] align=2.000 cohesion=0.000 noise=0.030 seed=1 | 0.85 runs/s
# [246/300] align=2.000 cohesion=0.000 noise=0.030 seed=2 | 0.85 runs/s
# [247/300] align=2.000 cohesion=0.000 noise=0.060 seed=0 | 0.85 runs/s
# [248/300] align=2.000 cohesion=0.000 noise=0.060 seed=1 | 0.85 runs/s
# [249/300] align=2.000 cohesion=0.000 noise=0.060 seed=2 | 0.85 runs/s
# [250/300] align=2.000 cohesion=0.000 noise=0.090 seed=0 | 0.85 runs/s
# [251/300] align=2.000 cohesion=0.000 noise=0.090 seed=1 | 0.85 runs/s
# [252/300] align=2.000 cohesion=0.000 noise=0.090 seed=2 | 0.85 runs/s
# [253/300] align=2.000 cohesion=0.000 noise=0.120 seed=0 | 0.85 runs/s
# [254/300] align=2.000 cohesion=0.000 noise=0.120 seed=1 | 0.85 runs/s
# [255/300] align=2.000 cohesion=0.000 noise=0.120 seed=2 | 0.85 runs/s
# [256/300] align=2.000 cohesion=0.200 noise=0.000 seed=0 | 0.85 runs/s
# [257/300] align=2.000 cohesion=0.200 noise=0.000 seed=1 | 0.85 runs/s
# [258/300] align=2.000 cohesion=0.200 noise=0.000 seed=2 | 0.85 runs/s
# [259/300] align=2.000 cohesion=0.200 noise=0.030 seed=0 | 0.85 runs/s
# [260/300] align=2.000 cohesion=0.200 noise=0.030 seed=1 | 0.85 runs/s
# [261/300] align=2.000 cohesion=0.200 noise=0.030 seed=2 | 0.85 runs/s
# [262/300] align=2.000 cohesion=0.200 noise=0.060 seed=0 | 0.85 runs/s
# [263/300] align=2.000 cohesion=0.200 noise=0.060 seed=1 | 0.85 runs/s
# [264/300] align=2.000 cohesion=0.200 noise=0.060 seed=2 | 0.85 runs/s
# [265/300] align=2.000 cohesion=0.200 noise=0.090 seed=0 | 0.85 runs/s
# [266/300] align=2.000 cohesion=0.200 noise=0.090 seed=1 | 0.85 runs/s
# [267/300] align=2.000 cohesion=0.200 noise=0.090 seed=2 | 0.85 runs/s
# [268/300] align=2.000 cohesion=0.200 noise=0.120 seed=0 | 0.85 runs/s
# [269/300] align=2.000 cohesion=0.200 noise=0.120 seed=1 | 0.85 runs/s
# [270/300] align=2.000 cohesion=0.200 noise=0.120 seed=2 | 0.85 runs/s
# [271/300] align=2.000 cohesion=0.400 noise=0.000 seed=0 | 0.85 runs/s
# [272/300] align=2.000 cohesion=0.400 noise=0.000 seed=1 | 0.85 runs/s
# [273/300] align=2.000 cohesion=0.400 noise=0.000 seed=2 | 0.85 runs/s
# [274/300] align=2.000 cohesion=0.400 noise=0.030 seed=0 | 0.85 runs/s
# [275/300] align=2.000 cohesion=0.400 noise=0.030 seed=1 | 0.85 runs/s
# [276/300] align=2.000 cohesion=0.400 noise=0.030 seed=2 | 0.85 runs/s
# [277/300] align=2.000 cohesion=0.400 noise=0.060 seed=0 | 0.85 runs/s
# [278/300] align=2.000 cohesion=0.400 noise=0.060 seed=1 | 0.85 runs/s
# [279/300] align=2.000 cohesion=0.400 noise=0.060 seed=2 | 0.85 runs/s
# [280/300] align=2.000 cohesion=0.400 noise=0.090 seed=0 | 0.85 runs/s
# [281/300] align=2.000 cohesion=0.400 noise=0.090 seed=1 | 0.85 runs/s
# [282/300] align=2.000 cohesion=0.400 noise=0.090 seed=2 | 0.85 runs/s
# [283/300] align=2.000 cohesion=0.400 noise=0.120 seed=0 | 0.85 runs/s
# [284/300] align=2.000 cohesion=0.400 noise=0.120 seed=1 | 0.85 runs/s
# [285/300] align=2.000 cohesion=0.400 noise=0.120 seed=2 | 0.85 runs/s
# [286/300] align=2.000 cohesion=0.600 noise=0.000 seed=0 | 0.85 runs/s
# [287/300] align=2.000 cohesion=0.600 noise=0.000 seed=1 | 0.85 runs/s
# [288/300] align=2.000 cohesion=0.600 noise=0.000 seed=2 | 0.85 runs/s
# [289/300] align=2.000 cohesion=0.600 noise=0.030 seed=0 | 0.85 runs/s
# [290/300] align=2.000 cohesion=0.600 noise=0.030 seed=1 | 0.85 runs/s
# [291/300] align=2.000 cohesion=0.600 noise=0.030 seed=2 | 0.85 runs/s
# [292/300] align=2.000 cohesion=0.600 noise=0.060 seed=0 | 0.85 runs/s
# [293/300] align=2.000 cohesion=0.600 noise=0.060 seed=1 | 0.85 runs/s
# [294/300] align=2.000 cohesion=0.600 noise=0.060 seed=2 | 0.85 runs/s
# [295/300] align=2.000 cohesion=0.600 noise=0.090 seed=0 | 0.85 runs/s
# [296/300] align=2.000 cohesion=0.600 noise=0.090 seed=1 | 0.85 runs/s
# [297/300] align=2.000 cohesion=0.600 noise=0.090 seed=2 | 0.85 runs/s
# [298/300] align=2.000 cohesion=0.600 noise=0.120 seed=0 | 0.86 runs/s
# [299/300] align=2.000 cohesion=0.600 noise=0.120 seed=1 | 0.86 runs/s
# [300/300] align=2.000 cohesion=0.600 noise=0.120 seed=2 | 0.86 runs/s
# saved: sweep3d_align_cohesion_noise.npz

# %%
# Choose one representative parameter point from the sweep grid
test_params = dict(sim_params)
test_params.update(
    align=1.0,
    cohesion=0.4,
    noise=0.06,
    seed=0,
)

# Run simulation once
history_test = run_simulation(**test_params)

# Compute metrics using the SAME function as in the sweep
metrics_test = compute_metrics(
    history_test,
    box_size=float(sim_params["box_size"]),
    burn_frac=0.6,
)

print("Alignment sanity check metrics:")
for k, v in metrics_test.items():
    print(f"{k:>20s}: {v:.6f}")
# Out:
# Alignment sanity check metrics:
#         density_mean: 2050.756765
#          density_std: 14.437576
#           hullV_mean: 0.760985
#            hullV_std: 0.007681
#            I2I1_mean: 0.935760
#             I2I1_std: 0.027953
#            I3I1_mean: 0.857986
#             I3I1_std: 0.013185
